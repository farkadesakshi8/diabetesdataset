# %%
#Exp No.:05

# %%
#Aim:Creation of array using numpy

# %%
#Name:Snehal Rajendra Pal
#Roll No.:43
#sec:C
#Sub:ET1

# %%
import numpy as np

# %%
#creating 1D array using numpy
a1=np.array([1,2,3,4])

# %%
a1
# Out:
# array([1, 2, 3, 4])

# %%
#recreating 2D array using numpy
a2=np.array([[1,3,4,5],[1,6,8,4]])

# %%
a2
# Out:
# array([[1, 3, 4, 5],
#        [1, 6, 8, 4]])
